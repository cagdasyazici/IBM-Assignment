# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Cagdas Yazici</b>

# %% [markdown]
# Buyer

# %% [markdown]
# *I am interested in data science because I love math and computer science*

# %% [markdown]
# <h3>My code is simple addition calculator</h3>

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %% [markdown]
# |----|----|----|
# |Stretch/Untouched|ProbDistribution|Accuracy|
# |----|----|----|
# |Stretched|Gaussian|843|
